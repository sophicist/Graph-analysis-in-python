# %%
from colorama import init
from termcolor import colored
import gspread as gs
from oauth2client.service_account import ServiceAccountCredentials
from termcolor import colored, cprint
import pandas as pd

# variables
nigeria = '1-IeLC87XXI34whlAIaRM0S7EiGDG6RQhqpMFtr6XuqA'

# %%
def Reader(link,sheet):
    gc = gs.service_account(filename='../../credentials.json')
    wks = gc.open_by_key(link)
    sheetname = wks.worksheet(sheet)
    record = pd.DataFrame(sheetname.get_all_records())
    return record

# Nigeria analysis
# aspirations
aspire = Reader(nigeria,"Aspirations and Strategy")
attitudes=Reader(nigeria,"Attitudes to and Adoption of Technology")
employee=Reader(nigeria,"Employee Qualitative Survey")
customerperson=Reader(nigeria,"Customer Survey In-Person")
supplierperson=Reader(nigeria,"Supplier Survey In Person")
supplierphone=Reader(nigeria,"Supplier Survey Phone Call")
customerphone=Reader(nigeria,"Customer Phone Call")
competition=Reader(nigeria,"Competition")
mckenzie=Reader(nigeria,"McKenzie")
decisions=Reader(nigeria,"Decision Making and Planning")
employeePPI=Reader(nigeria,"Employee PPI")
finance=Reader(nigeria,"Financial Tools")
formalization=Reader(nigeria,"Formalization")
observation=Reader(nigeria,"Observation Repeat")
gender=Reader(nigeria,"Gender")
records=Reader(nigeria,"Record Keeping")
byEmployer=Reader(nigeria,"Employees (by employer)")
specialevents=Reader(nigeria,"Special Events")
technology=Reader(nigeria,"Use of Technology")
manager=Reader(nigeria,"Manager")

# %% [markdown]
# # Aspirations and Strategy

# %%
class survey:
    def __init__(self,aspire):
        self.nigeria_aspire = aspire

    def yes_no_question(self,pattern,id_var,message):
        next_year = self.nigeria_aspire.copy()
        next_year = aspire[aspire.columns[aspire.columns.str.contains(pattern)]].melt(id_vars =id_var)
        next_year['survey'] = 'aspirations'
        next_year['Question']  = [i.split('_')[0] for i in next_year['variable']]
        next_year['answer']  = [i.split('_')[1] for i in next_year['variable']]
        next_year = next_year[next_year['value']=='Yes']
        print(f'{message}  ---> completed')
        next_year.columns = ['firm_id','variable','value','survey','question','answer']
        return next_year.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        next_year = self.nigeria_aspire.copy()
        next_year = aspire[aspire.columns[aspire.columns.str.contains(pattern)]].melt(id_vars =id_var)
        next_year = next_year[~next_year['variable'].str.contains("_feedback")]
        next_year['survey'] = 'aspirations'
        next_year['Question']  = [i.split('_')[0] for i in next_year['variable']]
        next_year['answer']  = [i.split('_')[1] for i in next_year['variable']]
        next_year = next_year[~next_year['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        next_year.columns = ['firm_id','variable','value','survey','question','answer']
        return next_year.drop('variable',axis =1)
# define a function for one question only

# %%
# aspirations
asp = survey(aspire)
yr_one      = asp.yes_no_question("Firm ID|SFD-AST-010",['Firm ID'],"Aspirations 1 year")
yr_five     = asp.yes_no_question("Firm ID|SFD-AST-020",['Firm ID'],"Aspirations 5 year")
measure     = asp.yes_no_question("Firm ID|SFD-AST-030",['Firm ID'],"Measure business")
often       = asp.other_question("Firm ID|SFD-AST-050",['Firm ID'],"often")
prices      = asp.yes_no_question("Firm ID|SFD-AST-070",['Firm ID'],"set_prices")
challenges  = asp.yes_no_question("Firm ID|SFD-AST-080",['Firm ID'],"challenges")

aspires = [yr_one,yr_five,measure,often,prices,challenges]
# Out:
# Aspirations 1 year  ---> completed
# Aspirations 5 year  ---> completed
# Measure business  ---> completed
# often  ---> completed
# set_prices  ---> completed
# challenges  ---> completed

# %% [markdown]
# # Attitudes to and Adoption of Technology

# %%
class survey:
    def __init__(self,attitudes):
        self.nigeria_attitudes = attitudes

    def yes_no_question(self,pattern,id_var,message):
        tech = self.nigeria_attitudes.copy()
        tech = attitudes[attitudes.columns[attitudes.columns.str.contains(pattern)]].melt(id_vars =id_var)
        tech['survey'] = 'attitudes'
        tech['Question']  = [i.split('_')[0] for i in tech['variable']]
        tech['answer'] = [i.split('_')[1] if len(i.split('_')) > 1 else '' for i in tech['variable']]
        tech = tech[tech['value']=='Yes']
        print(f'{message}  ---> completed')
        tech.columns = ['firm_id','variable','value','survey','question','answer']
        return tech.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        tech = self.nigeria_attitudes.copy()
        tech = attitudes[attitudes.columns[attitudes.columns.str.contains(pattern)]].melt(id_vars =id_var)
        tech = tech[~tech['variable'].str.contains("_feedback")]
        tech['survey'] = 'attitudes'
        tech['Question']  = [i.split('_')[0] for i in tech['variable']]
        tech['answer'] = [i.split('_')[1] if len(i.split('_')) > 1 else '' for i in tech['variable']]
        tech = tech[~tech['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        tech.columns = ['firm_id','variable','value','survey','question','answer']
        return tech.drop('variable',axis =1)
# attitudes
att = survey(attitudes)
adopt_tech  = att.yes_no_question("Firm ID|SFD-AAT-010",['Firm ID'],"Adopting Technology")
inform     = att.yes_no_question("Firm ID|SFD-AAT-020",['Firm ID'],"Information on Technology")
prevent     = att.yes_no_question("Firm ID|SFD-AAT-040",['Firm ID'],"Prevents from Technology")
digital       = att.other_question("Firm ID|SFD-AAT-060",['Firm ID'],"Digital payment")
reasons     = att.yes_no_question("Firm ID|SFD-AAT-070",['Firm ID'],"reasons")
reasons1     = att.other_question("Firm ID|SFD-AAT-050",['Firm ID'],"reasons1")
trade     = att.other_question("Firm ID|SFD-AAT-030",['Firm ID'],"trade")
reasons3     = att.other_question("Firm ID|SFD-AAT-080",['Firm ID'],"reasons3")
reasons4     = att.other_question("Firm ID|SFD-AAT-100",['Firm ID'],"reasons4")
reasons5     = att.other_question("Firm ID|SFD-AAT-120",['Firm ID'],"reasons5")
reasons6     = att.other_question("Firm ID|SFD-AAT-130",['Firm ID'],"reasons6")
reasons7     = att.other_question("Firm ID|SFD-AAT-140",['Firm ID'],"reasons7")
reasons8     = att.other_question("Firm ID|SFD-AAT-150",['Firm ID'],"reasons8")

attitudes = [adopt_tech,inform,prevent,digital,reasons,reasons1,trade,reasons3,reasons4,reasons5,reasons6,reasons7,reasons8]
# Out:
# Adopting Technology  ---> completed
# Information on Technology  ---> completed
# Prevents from Technology  ---> completed
# Digital payment  ---> completed
# reasons  ---> completed
# reasons1  ---> completed
# trade  ---> completed
# reasons3  ---> completed
# reasons4  ---> completed
# reasons5  ---> completed
# reasons6  ---> completed
# reasons7  ---> completed
# reasons8  ---> completed

# %% [markdown]
# # Employee Qualitative Survey

# %%
class survey:
    def __init__(self,employee):
        self.nigeria_employee = employee

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_employee.copy()
        inc = employee[employee.columns[employee.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'employee'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_employee.copy()
        inc = employee[employee.columns[employee.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'employee'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(employee)
other_inc = emp.yes_no_question("Firm ID|SFD-EMQ-010",['Firm ID'],"Other Income")
responsible  = emp.other_question("Firm ID|SFD-EMQ-020",['Firm ID'],"Responsible")
expense  = emp.yes_no_question("Firm ID|SFD-EMQ-040",['Firm ID'],"Major expense")
expectations  = emp.yes_no_question("Firm ID|SFD-EMQ-050",['Firm ID'],"Expected expense")
worry  = emp.other_question("Firm ID|SFD-EMQ-060",['Firm ID'],"Worry")
reduction  = emp.other_question("Firm ID|SFD-EMQ-070",['Firm ID'],"Unexpected reduction")
manage = emp.yes_no_question("Firm ID|SFD-EMQ-080",['Firm ID'],"Emergency expense")
source = emp.yes_no_question("Firm ID|SFD-EMQ-090",['Firm ID'],"Main source")
amount_of_work = emp.other_question("Firm ID|SFD-EMQ-100",['Firm ID'],"amount_of_work")
vary_seasons = emp.other_question("Firm ID|SFD-EMQ-110",['Firm ID'],"vary_seasons")
schedule = emp.other_question("Firm ID|SFD-EMQ-130",['Firm ID'],"Work_schedule")
receive = emp.yes_no_question("Firm ID|SFD-EMQ-140",['Firm ID'],"Received Work")
receive1 = emp.yes_no_question("Firm ID|SFD-EMQ-150",['Firm ID'],"Received money")
receive2 = emp.other_question("Firm ID|SFD-EMQ-160",['Firm ID'],"Overall income")
seasons = emp.other_question("Firm ID|SFD-EMQ-170",['Firm ID'],"Seasons")
total_inc = emp.other_question("Firm ID|SFD-EMQ-220",['Firm ID'],"Overall income")
seasons2 = emp.other_question("Firm ID|SFD-EMQ-230",['Firm ID'],"Seasons2")
others = emp.yes_no_question("Firm ID|SFD-EMQ-260",['Firm ID'],"Other Individuals")
who = emp.yes_no_question("Firm ID|SFD-EMQ-270",['Firm ID'],"who")
money_left = emp.yes_no_question("Firm ID|SFD-EMQ-300",['Firm ID'],"money_left")
use_money_left = emp.yes_no_question("Firm ID|SFD-EMQ-310",['Firm ID'],"use_money_left")
money_short = emp.yes_no_question("Firm ID|SFD-EMQ-320",['Firm ID'],"money_short")
credit = emp.yes_no_question("Firm ID|SFD-EMQ-330",['Firm ID'],"credit")
pay_loans = emp.yes_no_question("Firm ID|SFD-EMQ-360",['Firm ID'],"pay_loans")
account = emp.yes_no_question("Firm ID|SFD-EMQ-370",['Firm ID'],"account")
money_store = emp.other_question("Firm ID|SFD-EMQ-390",['Firm ID'],"money_store")
mobile_money = emp.yes_no_question("Firm ID|SFD-EMQ-470",['Firm ID'],"mobile_money")
mobile_money_store = emp.other_question("Firm ID|SFD-EMQ-500",['Firm ID'],"mobile_money_store")
money_transfer = emp.other_question("Firm ID|SFD-EMQ-510",['Firm ID'],"money_transfer")
mobile_banking = emp.yes_no_question("Firm ID|SFD-EMQ-520",['Firm ID'],"mobile_banking")
find_job = emp.other_question("Firm ID|SFD-EMQ-560",['Firm ID'],"find_job")
skills = emp.other_question("Firm ID|SFD-EMQ-570",['Firm ID'],"skills")
learn = emp.other_question("Firm ID|SFD-EMQ-580",['Firm ID'],"learn")

Employee = [other_inc,responsible,expense,expectations,worry,reduction,manage,source,amount_of_work,vary_seasons,schedule,receive,receive1,
           receive2,seasons,total_inc,seasons2,others,who,money_left,use_money_left,money_short,credit,pay_loans,account,money_store,mobile_money,
           mobile_money_store,money_transfer,mobile_banking,find_job,skills,learn]
# Out:
# Other Income  ---> completed
# Responsible  ---> completed
# Major expense  ---> completed
# Expected expense  ---> completed
# Worry  ---> completed
# Unexpected reduction  ---> completed
# Emergency expense  ---> completed
# Main source  ---> completed
# amount_of_work  ---> completed
# vary_seasons  ---> completed
# Work_schedule  ---> completed
# Received Work  ---> completed
# Received money  ---> completed
# Overall income  ---> completed
# Seasons  ---> completed
# Overall income  ---> completed
# Seasons2  ---> completed
# Other Individuals  ---> completed
# who  ---> completed
# money_left  ---> completed
# use_money_left  ---> completed
# money_short  ---> completed
# credit  ---> completed
# pay_loans  ---> completed
# account  ---> completed
# money_store  ---> completed
# mobile_money  ---> completed
# mobile_money_store  ---> completed
# money_transfer  ---> completed
# mobile_banking  ---> completed
# find_job  ---> completed
# skills  ---> completed
# ...

# %% [markdown]
# # Customer survey in-person

# %%
class survey:
    def __init__(self,customerperson):
        self.nigeria_customerperson = customerperson

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_customerperson.copy()
        inc = customerperson[customerperson.columns[customerperson.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'customerperson'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_customerperson.copy()
        inc = customerperson[customerperson.columns[customerperson.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'customerperson'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(customerperson)

buy = emp.yes_no_question("FIRM ID|SFD-CIP-020",['FIRM ID'],"Bought")
credit  = emp.other_question("FIRM ID|SFD-CIP-050",['FIRM ID'],"Credit")
pre_pay  = emp.other_question("FIRM ID|SFD-CIP-060",['FIRM ID'],"Pre-pay")
customer  = emp.other_question("FIRM ID|SFD-CIP-070",['FIRM ID'],"Customer")
main  = emp.other_question("FIRM ID|SFD-CIP-080",['FIRM ID'],"Main Income")
pay  = emp.other_question("FIRM ID|SFD-CIP-090",['FIRM ID'],"Pay")
offer = emp.other_question("FIRM ID|SFD-CIP-100",['FIRM ID'],"Offer")
select_firm = emp.yes_no_question("FIRM ID|SFD-CIP-110",['FIRM ID'],"Select_firm")
strong = emp.yes_no_question("FIRM ID|SFD-CIP-120",['FIRM ID'],"Strong")
differ_positive = emp.yes_no_question("FIRM ID|SFD-CIP-160",['FIRM ID'],"differ_positive")
differ_negative = emp.yes_no_question("FIRM ID|SFD-CIP-170",['FIRM ID'],"differ_negative")
mobile_phone = emp.yes_no_question("FIRM ID|SFD-CIP-180",['FIRM ID'],"Mobile phone")
type = emp.other_question("FIRM ID|SFD-CIP-190",['FIRM ID'],"Type of Phone")
digital_money = emp.yes_no_question("FIRM ID|SFD-CIP-200",['FIRM ID'],"Digital_money")
usage = emp.yes_no_question("FIRM ID|SFD-CIP-210",['FIRM ID'],"Use Digital Money")
prefer = emp.yes_no_question("FIRM ID|SFD-CIP-220",['FIRM ID'],"Prefer Digital Money")
money = emp.yes_no_question("FIRM ID|SFD-CIP-250",['FIRM ID'],"Use Digital Money anywhere")
purchase = emp.yes_no_question("FIRM ID|SFD-CIP-290",['FIRM ID'],"Type of purchase")
travel = emp.other_question("FIRM ID|SFD-CIP-300",['FIRM ID'],"Mode of travel")
know = emp.yes_no_question("FIRM ID|SFD-CIP-320",['FIRM ID'],"Connections")

customer_in_person = [buy,credit,pre_pay,customer,main,pay,offer,select_firm,strong,differ_positive,differ_negative,mobile_phone,type,
                      digital_money,usage,prefer,money,purchase,travel,know]
# Out:
# Bought  ---> completed
# Credit  ---> completed
# Pre-pay  ---> completed
# Customer  ---> completed
# Main Income  ---> completed
# Pay  ---> completed
# Offer  ---> completed
# Select_firm  ---> completed
# Strong  ---> completed
# differ_positive  ---> completed
# differ_negative  ---> completed
# Mobile phone  ---> completed
# Type of Phone  ---> completed
# Digital_money  ---> completed
# Use Digital Money  ---> completed
# Prefer Digital Money  ---> completed
# Use Digital Money anywhere  ---> completed
# Type of purchase  ---> completed
# Mode of travel  ---> completed
# Connections  ---> completed

# %% [markdown]
# # customer phone call

# %%
class survey:
    def __init__(self,customerphone):
        self.nigeria_customerphone = customerphone

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_customerphone.copy()
        inc = customerphone[customerphone.columns[customerphone.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'customerphone'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_customerphone.copy()
        inc = customerphone[customerphone.columns[customerphone.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'customerphone'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(customerphone)

buy = emp.yes_no_question("FIRM ID|SFD-CPC-020",['FIRM ID'],"Bought")
credit  = emp.other_question("FIRM ID|SFD-CPC-050",['FIRM ID'],"Credit")
pre_pay  = emp.other_question("FIRM ID|SFD-CPC-060",['FIRM ID'],"Pre-pay")
customer  = emp.other_question("FIRM ID|SFD-CPC-070",['FIRM ID'],"Customer")
main  = emp.other_question("FIRM ID|SFD-CPC-080",['FIRM ID'],"Main Income")
pay  = emp.other_question("FIRM ID|SFD-CPC-090",['FIRM ID'],"Pay")
offer = emp.other_question("FIRM ID|SFD-CPC-100",['FIRM ID'],"Offer")
select_firm = emp.yes_no_question("FIRM ID|SFD-CPC-110",['FIRM ID'],"Select_firm")
strong = emp.yes_no_question("FIRM ID|SFD-CPC-120",['FIRM ID'],"Strong")
differ_positive = emp.yes_no_question("FIRM ID|SFD-CPC-160",['FIRM ID'],"differ_positive")
differ_negative = emp.yes_no_question("FIRM ID|SFD-CPC-170",['FIRM ID'],"differ_negative")
mobile_phone = emp.yes_no_question("FIRM ID|SFD-CPC-180",['FIRM ID'],"Mobile phone")
type = emp.other_question("FIRM ID|SFD-CPC-190",['FIRM ID'],"Type of Phone")
digital_money = emp.yes_no_question("FIRM ID|SFD-CPC-200",['FIRM ID'],"Digital_money")
usage = emp.yes_no_question("FIRM ID|SFD-CPC-210",['FIRM ID'],"Use Digital Money")
prefer = emp.yes_no_question("FIRM ID|SFD-CPC-220",['FIRM ID'],"Prefer Digital Money")
money = emp.yes_no_question("FIRM ID|SFD-CPC-250",['FIRM ID'],"Use Digital Money anywhere")
purchase = emp.yes_no_question("FIRM ID|SFD-CPC-290",['FIRM ID'],"Type of purchase")
travel = emp.other_question("FIRM ID|SFD-CPC-300",['FIRM ID'],"Mode of travel")
know = emp.yes_no_question("FIRM ID|SFD-CPC-320",['FIRM ID'],"Connections")

customer_phone = [buy,credit,pre_pay,customer,main,pay,offer,select_firm,strong,differ_positive,differ_negative,mobile_phone,type,
                      digital_money,usage,prefer,money,purchase,travel,know]
# Out:
# Bought  ---> completed
# Credit  ---> completed
# Pre-pay  ---> completed
# Customer  ---> completed
# Main Income  ---> completed
# Pay  ---> completed
# Offer  ---> completed
# Select_firm  ---> completed
# Strong  ---> completed
# differ_positive  ---> completed
# differ_negative  ---> completed
# Mobile phone  ---> completed
# Type of Phone  ---> completed
# Digital_money  ---> completed
# Use Digital Money  ---> completed
# Prefer Digital Money  ---> completed
# Use Digital Money anywhere  ---> completed
# Type of purchase  ---> completed
# Mode of travel  ---> completed
# Connections  ---> completed

# %% [markdown]
# # supplier in-person survey

# %%
class survey:
    def __init__(self,supplierperson):
        self.nigeria_supplierperson = supplierperson

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_supplierperson.copy()
        inc = supplierperson[supplierperson.columns[supplierperson.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'supplierperson'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_supplierperson.copy()
        inc = supplierperson[supplierperson.columns[supplierperson.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'supplierperson'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(supplierperson)

business = emp.yes_no_question("FIRM ID|SFD-SPP-020",['FIRM ID'],"Business")
other  = emp.other_question("FIRM ID|SFD-SPP-030",['FIRM ID'],"other business")
locations  = emp.other_question("FIRM ID|SFD-SPP-040",['FIRM ID'],"Locations")
size  = emp.other_question("FIRM ID|SFD-SPP-060",['FIRM ID'],"size of business")
customer  = emp.other_question("FIRM ID|SFD-SPP-070",['FIRM ID'],"Customer")
relations = emp.other_question("FIRM ID|SFD-SPP-080",['FIRM ID'],"Relations")
closed = emp.other_question("FIRM ID|SFD-SPP-120",['FIRM ID'],"Closed_down")
competitors = emp.yes_no_question("FIRM ID|SFD-SPP-140",['FIRM ID'],"Competitors")
prices = emp.other_question("FIRM ID|SFD-SPP-180",['FIRM ID'],"Prices")
sell = emp.other_question("FIRM ID|SFD-SPP-190",['FIRM ID'],"sell")
raise_price = emp.other_question("FIRM ID|SFD-SPP-200",['FIRM ID'],"raise")
past = emp.other_question("FIRM ID|SFD-SPP-210",['FIRM ID'],"past")
payment = emp.other_question("FIRM ID|SFD-SPP-250",['FIRM ID'],"Payment")
full_payment = emp.yes_no_question("FIRM ID|SFD-SPP-270",['FIRM ID'],"full_payment")
credit = emp.other_question("FIRM ID|SFD-SPP-300",['FIRM ID'],"Credit")
different_pay = emp.yes_no_question("FIRM ID|SFD-SPP-310",['FIRM ID'],"Different pay")
instalment = emp.other_question("FIRM ID|SFD-SPP-330",['FIRM ID'],"Instalment")
amount = emp.other_question("FIRM ID|SFD-SPP-340",['FIRM ID'],"amount")
plans = emp.yes_no_question("FIRM ID|SFD-SPP-350",['FIRM ID'],"Plans")
mode = emp.other_question("FIRM ID|SFD-SPP-370",['FIRM ID'],"payment_mode")
complete_order = emp.other_question("FIRM ID|SFD-SPP-380",['FIRM ID'],"complete_order")
delivery = emp.yes_no_question("FIRM ID|SFD-SPP-390",['FIRM ID'],"delivery")
charge = emp.yes_no_question("FIRM ID|SFD-SPP-400",['FIRM ID'],"charge")
fluctuate = emp.other_question("FIRM ID|SFD-SPP-410",['FIRM ID'],"fluctuate")

supplierperson = [business,other,locations,size,customer,relations,closed,competitors,prices,sell,raise_price,past,payment,full_payment,credit,
                 different_pay,instalment,amount,plans,mode,complete_order,delivery,charge,fluctuate]
# Out:
# Business  ---> completed
# other business  ---> completed
# Locations  ---> completed
# size of business  ---> completed
# Customer  ---> completed
# Relations  ---> completed
# Closed_down  ---> completed
# Competitors  ---> completed
# Prices  ---> completed
# sell  ---> completed
# raise  ---> completed
# past  ---> completed
# Payment  ---> completed
# full_payment  ---> completed
# Credit  ---> completed
# Different pay  ---> completed
# Instalment  ---> completed
# amount  ---> completed
# Plans  ---> completed
# payment_mode  ---> completed
# complete_order  ---> completed
# delivery  ---> completed
# charge  ---> completed
# fluctuate  ---> completed

# %% [markdown]
# # supplier phone call

# %%
class survey:
    def __init__(self,supplierphone):
        self.nigeria_supplierphone = supplierphone

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_supplierphone.copy()
        inc = supplierphone[supplierphone.columns[supplierphone.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'supplierphone'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_supplierphone.copy()
        inc = supplierphone[supplierphone.columns[supplierphone.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'supplierphone'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(supplierphone)

business = emp.yes_no_question("FIRM ID|SFD-SPP-020",['FIRM ID'],"Business")
other  = emp.other_question("FIRM ID|SFD-SPP-030",['FIRM ID'],"other business")
locations  = emp.other_question("FIRM ID|SFD-SPP-040",['FIRM ID'],"Locations")
size  = emp.other_question("FIRM ID|SFD-SPP-060",['FIRM ID'],"size of business")
customer  = emp.other_question("FIRM ID|SFD-SPP-070",['FIRM ID'],"Customer")
relations = emp.other_question("FIRM ID|SFD-SPP-080",['FIRM ID'],"Relations")
closed = emp.other_question("FIRM ID|SFD-SPP-120",['FIRM ID'],"Closed_down")
competitors = emp.yes_no_question("FIRM ID|SFD-SPP-140",['FIRM ID'],"Competitors")
prices = emp.other_question("FIRM ID|SFD-SPP-180",['FIRM ID'],"Prices")
sell = emp.other_question("FIRM ID|SFD-SPP-190",['FIRM ID'],"sell")
raise_price = emp.other_question("FIRM ID|SFD-SPP-200",['FIRM ID'],"raise")
past = emp.other_question("FIRM ID|SFD-SPP-210",['FIRM ID'],"past")
payment = emp.other_question("FIRM ID|SFD-SPP-250",['FIRM ID'],"Payment")
full_payment = emp.yes_no_question("FIRM ID|SFD-SPP-270",['FIRM ID'],"full_payment")
credit = emp.other_question("FIRM ID|SFD-SPP-300",['FIRM ID'],"Credit")
different_pay = emp.yes_no_question("FIRM ID|SFD-SPP-310",['FIRM ID'],"Different pay")
instalment = emp.other_question("FIRM ID|SFD-SPP-330",['FIRM ID'],"Instalment")
amount = emp.yes_no_question("FIRM ID|SFD-SPP-340",['FIRM ID'],"amount")
plans = emp.yes_no_question("FIRM ID|SFD-SPP-350",['FIRM ID'],"Plans")
mode = emp.other_question("FIRM ID|SFD-SPP-370",['FIRM ID'],"payment_mode")
complete_order = emp.other_question("FIRM ID|SFD-SPP-380",['FIRM ID'],"complete_order")
delivery = emp.yes_no_question("FIRM ID|SFD-SPP-390",['FIRM ID'],"delivery")
charge = emp.yes_no_question("FIRM ID|SFD-SPP-400",['FIRM ID'],"charge")
fluctuate = emp.other_question("FIRM ID|SFD-SPP-410",['FIRM ID'],"fluctuate")

supplierphone = [business,other,locations,size,customer,relations,closed,competitors,prices,sell,raise_price,past,payment,full_payment,credit,
                 different_pay,instalment,amount,plans,mode,complete_order,delivery,charge,fluctuate]
# Out:
# Business  ---> completed
# other business  ---> completed
# Locations  ---> completed
# size of business  ---> completed
# Customer  ---> completed
# Relations  ---> completed
# Closed_down  ---> completed
# Competitors  ---> completed
# Prices  ---> completed
# sell  ---> completed
# raise  ---> completed
# past  ---> completed
# Payment  ---> completed
# full_payment  ---> completed
# Credit  ---> completed
# Different pay  ---> completed
# Instalment  ---> completed
# amount  ---> completed
# Plans  ---> completed
# payment_mode  ---> completed
# complete_order  ---> completed
# delivery  ---> completed
# charge  ---> completed
# fluctuate  ---> completed

# %% [markdown]
# # competition survey

# %%
class survey:
    def __init__(self,competition):
        self.nigeria_competition = competition

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_competition.copy()
        inc = competition[competition.columns[competition.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'competition'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_competition.copy()
        inc = competition[competition.columns[competition.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'competition'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(competition)

business = emp.other_question("FIRM ID|SFD-CMP-010",['FIRM ID'],"business")
other  = emp.other_question("FIRM ID|SFD-CMP-020",['FIRM ID'],"other business")
locations  = emp.other_question("FIRM ID|SFD-CMP-040",['FIRM ID'],"Locations")
size  = emp.yes_no_question("FIRM ID|SFD-CMP-050",['FIRM ID'],"size of business")
customer  = emp.yes_no_question("FIRM ID|SFD-CMP-060",['FIRM ID'],"Customer")
trade  = emp.other_question("FIRM ID|SFD-CMP-070",['FIRM ID'],"trade")
relations = emp.other_question("FIRM ID|SFD-CMP-080",['FIRM ID'],"Relations")
closed = emp.other_question("FIRM ID|SFD-CMP-090",['FIRM ID'],"Closed_down")
competitors = emp.yes_no_question("FIRM ID|SFD-CMP-100",['FIRM ID'],"Competitors")
prices = emp.yes_no_question("FIRM ID|SFD-CMP-120",['FIRM ID'],"Prices")
sell = emp.yes_no_question("FIRM ID|SFD-CMP-140",['FIRM ID'],"sell")

competition = [business,other,locations,size,customer,trade,relations,closed,competitors,prices,sell]
# Out:
# business  ---> completed
# other business  ---> completed
# Locations  ---> completed
# size of business  ---> completed
# Customer  ---> completed
# trade  ---> completed
# Relations  ---> completed
# Closed_down  ---> completed
# Competitors  ---> completed
# Prices  ---> completed
# sell  ---> completed

# %% [markdown]
# # mckenzie survey

# %%
class survey:
    def __init__(self,mckenzie):
        self.nigeria_mckenzie = mckenzie

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_mckenzie.copy()
        inc = mckenzie[mckenzie.columns[mckenzie.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'mckenzie'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_mckenzie.copy()
        inc = mckenzie[mckenzie.columns[mckenzie.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'mckenzie'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(mckenzie)

business = emp.yes_no_question("FIRM ID|SFD-MBP-010",['FIRM ID'],"business")
other  = emp.yes_no_question("FIRM ID|SFD-MBP-020",['FIRM ID'],"other business")
locations  = emp.yes_no_question("FIRM ID|SFD-MBP-030",['FIRM ID'],"Locations")
size  = emp.yes_no_question("FIRM ID|SFD-MBP-040",['FIRM ID'],"size of business")
customer  = emp.yes_no_question("FIRM ID|SFD-MBP-050",['FIRM ID'],"Customer")
relations = emp.other_question("FIRM ID|SFD-MBP-060",['FIRM ID'],"Relations")
closed = emp.yes_no_question("FIRM ID|SFD-MBP-070",['FIRM ID'],"Closed_down")
competitors = emp.other_question("FIRM ID|SFD-MBP-080",['FIRM ID'],"Competitors")
sell = emp.other_question("FIRM ID|SFD-MBP-100",['FIRM ID'],"sell")
stock = emp.other_question("FIRM ID|SFD-MBP-110",['FIRM ID'],"stock")
record = emp.yes_no_question("FIRM ID|SFD-MBP-120",['FIRM ID'],"record")
system = emp.other_question("FIRM ID|SFD-MBP-130",['FIRM ID'],"system")
update = emp.other_question("FIRM ID|SFD-MBP-140",['FIRM ID'],"update")
written = emp.yes_no_question("FIRM ID|SFD-MBP-150",['FIRM ID'],"written")
purchase = emp.yes_no_question("FIRM ID|SFD-MBP-160",['FIRM ID'],"purchase")
cash = emp.yes_no_question("FIRM ID|SFD-MBP-170",['FIRM ID'],"cash")
increase = emp.yes_no_question("FIRM ID|SFD-MBP-180",['FIRM ID'],"increase")
product = emp.yes_no_question("FIRM ID|SFD-MBP-190",['FIRM ID'],"product")
profit = emp.yes_no_question("FIRM ID|SFD-MBP-200",['FIRM ID'],"profit")
budget = emp.yes_no_question("FIRM ID|SFD-MBP-210",['FIRM ID'],"budget")
goods = emp.yes_no_question("FIRM ID|SFD-MBP-220",['FIRM ID'],"goods")
loan = emp.yes_no_question("FIRM ID|SFD-MBP-230",['FIRM ID'],"loan")
bank = emp.yes_no_question("FIRM ID|SFD-MBP-240",['FIRM ID'],"bank")
finance = emp.other_question("FIRM ID|SFD-MBP-250",['FIRM ID'],"finance")
year = emp.yes_no_question("FIRM ID|SFD-MBP-260",['FIRM ID'],"year")
annually = emp.yes_no_question("FIRM ID|SFD-MBP-270",['FIRM ID'],"annually")

mckenzie = [business,other,locations,size,customer,relations,closed,competitors,sell,stock,record,system,update,written,purchase,cash,increase,
           product,profit,budget,goods,loan,bank,finance,year,annually]
# Out:
# business  ---> completed
# other business  ---> completed
# Locations  ---> completed
# size of business  ---> completed
# Customer  ---> completed
# Relations  ---> completed
# Closed_down  ---> completed
# Competitors  ---> completed
# sell  ---> completed
# stock  ---> completed
# record  ---> completed
# system  ---> completed
# update  ---> completed
# written  ---> completed
# purchase  ---> completed
# cash  ---> completed
# increase  ---> completed
# product  ---> completed
# profit  ---> completed
# budget  ---> completed
# goods  ---> completed
# loan  ---> completed
# bank  ---> completed
# finance  ---> completed
# year  ---> completed
# annually  ---> completed

# %% [markdown]
# # Decision Making and Planning

# %%
class survey:
    def __init__(self,decisions):
        self.nigeria_decisions = decisions

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_decisions.copy()
        inc = decisions[decisions.columns[decisions.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'decisions'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_decisions.copy()
        inc = decisions[decisions.columns[decisions.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'decisions'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(decisions)

business = emp.other_question("FIRM ID|SFD-DMP-020",['FIRM ID'],"business")
other  = emp.yes_no_question("FIRM ID|SFD-DMP-030",['FIRM ID'],"other business")
locations  = emp.yes_no_question("FIRM ID|SFD-DMP-040",['FIRM ID'],"Locations")
size  = emp.other_question("FIRM ID|SFD-DMP-050",['FIRM ID'],"size of business")
customer  = emp.yes_no_question("FIRM ID|SFD-DMP-070",['FIRM ID'],"Customer")
relations = emp.other_question("FIRM ID|SFD-DMP-080",['FIRM ID'],"Relations")
closed = emp.other_question("FIRM ID|SFD-DMP-090",['FIRM ID'],"Closed_down")
competitors = emp.other_question("FIRM ID|SFD-DMP-100",['FIRM ID'],"Competitors")
prices = emp.yes_no_question("FIRM ID|SFD-DMP-120",['FIRM ID'],"Prices")

decisions = [business,other,locations,size,customer,relations,closed,competitors,prices]
# Out:
# business  ---> completed
# other business  ---> completed
# Locations  ---> completed
# size of business  ---> completed
# Customer  ---> completed
# Relations  ---> completed
# Closed_down  ---> completed
# Competitors  ---> completed
# Prices  ---> completed

# %% [markdown]
# # employee PPI

# %%
class survey:
    def __init__(self,employeePPI):
        self.nigeria_employeePPI = employeePPI

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_employeePPI.copy()
        inc = employeePPI[employeePPI.columns[employeePPI.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'employeePPI'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_employeePPI.copy()
        inc = employeePPI[employeePPI.columns[employeePPI.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'employeePPI'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(employeePPI)

business = emp.other_question("FIRM ID|SFD-EPP-000",['FIRM ID'],"business")
other  = emp.other_question("FIRM ID|SFD-EPP-010",['FIRM ID'],"other business")
locations  = emp.other_question("FIRM ID|SFD-EPP-020",['FIRM ID'],"Locations")
size  = emp.other_question("FIRM ID|SFD-EPP-030",['FIRM ID'],"size of business")
customer  = emp.yes_no_question("FIRM ID|SFD-EPP-040",['FIRM ID'],"Customer")
relations = emp.other_question("FIRM ID|SFD-EPP-050",['FIRM ID'],"Relations")
closed = emp.yes_no_question("FIRM ID|SFD-EPP-060",['FIRM ID'],"Closed_down")
competitors = emp.other_question("FIRM ID|SFD-EPP-070",['FIRM ID'],"Competitors")
prices = emp.other_question("FIRM ID|SFD-EPP-080",['FIRM ID'],"Prices")
sell = emp.other_question("FIRM ID|SFD-EPP-090",['FIRM ID'],"sell")
stock = emp.yes_no_question("FIRM ID|SFD-EPP-150",['FIRM ID'],"stock")
record = emp.yes_no_question("FIRM ID|SFD-EPP-170",['FIRM ID'],"record")
system = emp.yes_no_question("FIRM ID|SFD-EPP-190",['FIRM ID'],"system")
update = emp.other_question("FIRM ID|SFD-EPP-200 ",['FIRM ID'],"update")
written = emp.yes_no_question("FIRM ID|SFD-EPP-210",['FIRM ID'],"written")
purchase = emp.yes_no_question("FIRM ID|SFD-EPP-214",['FIRM ID'],"purchase")
cash = emp.yes_no_question("FIRM ID|SFD-EPP-230",['FIRM ID'],"cash")
increase = emp.other_question("FIRM ID|SFD-EPP-240",['FIRM ID'],"increase")
product = emp.yes_no_question("FIRM ID|SFD-EPP-250",['FIRM ID'],"product")
profit = emp.other_question("FIRM ID|SFD-EPP-290",['FIRM ID'],"profit")

employeePPI = [business,other,locations,size,customer,relations,closed,competitors,prices,sell,stock,record,system,
               update,written,purchase,cash,increase,product,profit]
# Out:
# business  ---> completed
# other business  ---> completed
# Locations  ---> completed
# size of business  ---> completed
# Customer  ---> completed
# Relations  ---> completed
# Closed_down  ---> completed
# Competitors  ---> completed
# Prices  ---> completed
# sell  ---> completed
# stock  ---> completed
# record  ---> completed
# system  ---> completed
# update  ---> completed
# written  ---> completed
# purchase  ---> completed
# cash  ---> completed
# increase  ---> completed
# product  ---> completed
# profit  ---> completed

# %% [markdown]
# # financial tools

# %%
class survey:
    def __init__(self,finance):
        self.nigeria_finance = finance

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_finance.copy()
        inc = finance[finance.columns[finance.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'finance'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_finance.copy()
        inc = finance[finance.columns[finance.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'finance'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(finance)
other_inc = emp.yes_no_question("firm_id|SFD-FTA-010", ['firm_id'], "Other Income")
responsible = emp.other_question("firm_id|SFD-FTA-020", ['firm_id'], "Responsible")
expense = emp.yes_no_question("firm_id|SFD-FTA-030", ['firm_id'], "Major expense")
expectations = emp.other_question("firm_id|SFD-FTA-040", ['firm_id'], "Expected expense")
worry = emp.other_question("firm_id|SFD-FTA-050", ['firm_id'], "Worry")
reduction = emp.other_question("firm_id|SFD-FTA-060", ['firm_id'], "Unexpected reduction")
manage = emp.other_question("firm_id|SFD-FTA-070", ['firm_id'], "Emergency expense")
source = emp.yes_no_question("firm_id|SFD-FTA-090", ['firm_id'], "Main source")
amount_of_work = emp.yes_no_question("firm_id|SFD-FTA-100", ['firm_id'], "amount_of_work")
vary_seasons = emp.yes_no_question("firm_id|SFD-FTA-110", ['firm_id'], "vary_seasons")
schedule = emp.yes_no_question("firm_id|SFD-FTA-120", ['firm_id'], "Work_schedule")
receive = emp.yes_no_question("firm_id|SFD-FTA-130", ['firm_id'], "Received Work")
receive1 = emp.yes_no_question("firm_id|SFD-FTA-160", ['firm_id'], "Received money")
receive2 = emp.yes_no_question("firm_id|SFD-FTA-170", ['firm_id'], "Overall income")
seasons = emp.yes_no_question("firm_id|SFD-FTA-180", ['firm_id'], "Seasons")
total_inc = emp.other_question("firm_id|SFD-FTA-190", ['firm_id'], "Overall income")
seasons2 = emp.other_question("firm_id|SFD-FTA-200", ['firm_id'], "Seasons2")
others = emp.other_question("firm_id|SFD-FTA-210", ['firm_id'], "Other Individuals")
who = emp.yes_no_question("firm_id|SFD-FTA-230", ['firm_id'], "who")
money_left = emp.yes_no_question("firm_id|SFD-FTA-240", ['firm_id'], "money_left")
use_money_left = emp.yes_no_question("firm_id|SFD-FTA-250", ['firm_id'], "use_money_left")
money_short = emp.yes_no_question("firm_id|SFD-ETA-260", ['firm_id'], "money_short")
credit = emp.yes_no_question("firm_id|SFD-FTA-270", ['firm_id'], "credit")
pay_loans = emp.other_question("firm_id|SFD-FTA-280", ['firm_id'], "pay_loans")
account = emp.other_question("firm_id|SFD-FTA-290", ['firm_id'], "account")
money_store = emp.other_question("firm_id|SFD-FTA-310", ['firm_id'], "money_store")
mobile_money = emp.yes_no_question("firm_id|SFD-FTA-320",['firm_id'],"mobile_money")
mobile_money_store = emp.yes_no_question("firm_id|SFD-FTA-330",['firm_id'],"mobile_money_store")
money_transfer = emp.yes_no_question("firm_id|SFD-FTA-340",['firm_id'],"money_transfer")
mobile_banking = emp.other_question("firm_id|SFD-FTA-350",['firm_id'],"mobile_banking")
find_job = emp.yes_no_question("firm_id|SFD-FTA-360",['firm_id'],"find_job")

finance = [other_inc,responsible,expense,expectations,worry,reduction,manage,source,amount_of_work,vary_seasons,schedule,receive,receive1,
           receive2,seasons,total_inc,seasons2,others,who,money_left,use_money_left,money_short,credit,pay_loans,account,money_store,mobile_money,
           mobile_money_store,money_transfer,mobile_banking,find_job]
# Out:
# Other Income  ---> completed
# Responsible  ---> completed
# Major expense  ---> completed
# Expected expense  ---> completed
# Worry  ---> completed
# Unexpected reduction  ---> completed
# Emergency expense  ---> completed
# Main source  ---> completed
# amount_of_work  ---> completed
# vary_seasons  ---> completed
# Work_schedule  ---> completed
# Received Work  ---> completed
# Received money  ---> completed
# Overall income  ---> completed
# Seasons  ---> completed
# Overall income  ---> completed
# Seasons2  ---> completed
# Other Individuals  ---> completed
# who  ---> completed
# money_left  ---> completed
# use_money_left  ---> completed
# money_short  ---> completed
# credit  ---> completed
# pay_loans  ---> completed
# account  ---> completed
# money_store  ---> completed
# mobile_money  ---> completed
# mobile_money_store  ---> completed
# money_transfer  ---> completed
# mobile_banking  ---> completed
# find_job  ---> completed

# %% [markdown]
# # formalization survey

# %%
class survey:
    def __init__(self,formalization):
        self.nigeria_formalization = formalization

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_formalization.copy()
        inc = formalization[formalization.columns[formalization.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'formalization'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_formalization.copy()
        inc = formalization[formalization.columns[formalization.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'formalization'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(formalization)
other_inc = emp.yes_no_question("Firm ID|SFD-FOR-010",['Firm ID'],"Other Income")
responsible  = emp.yes_no_question("Firm ID|SFD-FOR-020",['Firm ID'],"Responsible")
expense  = emp.yes_no_question("Firm ID|SFD-FOR-030",['Firm ID'],"Major expense")
expectations  = emp.other_question("Firm ID|SFD-FOR-040",['Firm ID'],"Expected expense")
worry  = emp.yes_no_question("Firm ID|SFD-FOR-050",['Firm ID'],"Worry")
reduction  = emp.other_question("Firm ID|SFD-FOR-060",['Firm ID'],"Unexpected reduction")

formalization = [other_inc,responsible,expense,expectations,worry,reduction]
# Out:
# Other Income  ---> completed
# Responsible  ---> completed
# Major expense  ---> completed
# Expected expense  ---> completed
# Worry  ---> completed
# Unexpected reduction  ---> completed

# %% [markdown]
# # gender survey

# %%
class survey:
    def __init__(self,gender):
        self.nigeria_gender = gender

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_gender.copy()
        inc = gender[gender.columns[gender.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'gender'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_gender.copy()
        inc = gender[gender.columns[gender.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'gender'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(gender)
other_inc = emp.other_question("Firm ID|SFD-GND-010",['Firm ID'],"Other Income")
responsible  = emp.other_question("Firm ID|SFD-GND-020",['Firm ID'],"Responsible")
expense  = emp.other_question("Firm ID|SFD-GND-030",['Firm ID'],"Major expense")
expectations  = emp.other_question("Firm ID|SFD-GND-040",['Firm ID'],"Expected expense")
worry  = emp.other_question("Firm ID|SFD-GND-050",['Firm ID'],"Worry")
reduction  = emp.other_question("Firm ID|SFD-GND-060",['Firm ID'],"Unexpected reduction")
pay_loans = emp.other_question("Firm ID|SFD-GND-070", ['Firm ID'], "pay_loans")
account = emp.other_question("Firm ID|SFD-GND-080", ['Firm ID'], "account")
money_store = emp.other_question("Firm ID|SFD-GND-090", ['Firm ID'], "money_store")
mobile_money = emp.other_question("Firm ID|SFD-GND-100",['Firm ID'],"mobile_money")
mobile_money_store = emp.other_question("Firm ID|SFD-GND-110",['Firm ID'],"mobile_money_store")
money_transfer = emp.other_question("Firm ID|SFD-GND-120",['Firm ID'],"money_transfer")
mobile_banking = emp.other_question("Firm ID|SFD-GND-130",['Firm ID'],"mobile_banking")
find_job = emp.other_question("Firm ID|SFD-GND-140",['Firm ID'],"find_job")
clean = emp.other_question("Firm ID|SFD-GND-150",['Firm ID'],"clean")
food = emp.other_question("Firm ID|SFD-GND-160",['Firm ID'],"food")
children = emp.other_question("Firm ID|SFD-GND-170",['Firm ID'],"children")
girl = emp.other_question("Firm ID|SFD-GND-180",['Firm ID'],"girl")
boy = emp.other_question("Firm ID|SFD-GND-190",['Firm ID'],"boy")
agree = emp.other_question("Firm ID|SFD-GND-200",['Firm ID'],"agree")


gender = [other_inc,responsible,expense,expectations,worry,reduction,pay_loans,account,money_store,mobile_money,
           mobile_money_store,money_transfer,mobile_banking,find_job,clean,food,children,girl,boy,agree]
# Out:
# Other Income  ---> completed
# Responsible  ---> completed
# Major expense  ---> completed
# Expected expense  ---> completed
# Worry  ---> completed
# Unexpected reduction  ---> completed
# pay_loans  ---> completed
# account  ---> completed
# money_store  ---> completed
# mobile_money  ---> completed
# mobile_money_store  ---> completed
# money_transfer  ---> completed
# mobile_banking  ---> completed
# find_job  ---> completed
# clean  ---> completed
# food  ---> completed
# children  ---> completed
# girl  ---> completed
# boy  ---> completed
# agree  ---> completed

# %% [markdown]
# # record keeping survey

# %%
class survey:
    def __init__(self,records):
        self.nigeria_records = records

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_records.copy()
        inc = records[records.columns[records.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'records'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_records.copy()
        inc = records[records.columns[records.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'records'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(records)
other_inc = emp.yes_no_question("Firm ID|SFD-RCK-020",['Firm ID'],"Other Income")
responsible  = emp.other_question("Firm ID|SFD-RCK-050",['Firm ID'],"Responsible")
expense  = emp.yes_no_question("Firm ID|SFD-RCK-060",['Firm ID'],"Major expense")
expectations  = emp.yes_no_question("Firm ID|SFD-RCK-070",['Firm ID'],"Expected expense")
worry  = emp.other_question("Firm ID|SFD-RCK-080",['Firm ID'],"Worry")
reduction  = emp.other_question("Firm ID|SFD-RCK-100",['Firm ID'],"Unexpected reduction")
pay_loans = emp.yes_no_question("Firm ID|SFD-RCK-120", ['Firm ID'], "pay_loans")
account = emp.yes_no_question("Firm ID|SFD-RCK-150", ['Firm ID'], "account")
money_store = emp.yes_no_question("Firm ID|SFD-RCK-160", ['Firm ID'], "money_store")
mobile_money = emp.other_question("Firm ID|SFD-RCK-170",['Firm ID'],"mobile_money")
mobile_money_store = emp.other_question("Firm ID|SFD-RCK-180",['Firm ID'],"mobile_money_store")
money_transfer = emp.yes_no_question("Firm ID|SFD-RCK-190",['Firm ID'],"money_transfer")
mobile_banking = emp.other_question("Firm ID|SFD-CSQ-210",['Firm ID'],"mobile_banking")
find_job = emp.other_question("Firm ID|SFD-CSQ-230",['Firm ID'],"find_job")
clean = emp.other_question("Firm ID|SFD-CSQ-240",['Firm ID'],"clean")
food = emp.other_question("Firm ID|SFD-CSQ-260",['Firm ID'],"food")


records = [other_inc,responsible,expense,expectations,worry,reduction,pay_loans,account,money_store,mobile_money,
           mobile_money_store,money_transfer,mobile_banking,find_job,clean,food]
# Out:
# Other Income  ---> completed
# Responsible  ---> completed
# Major expense  ---> completed
# Expected expense  ---> completed
# Worry  ---> completed
# Unexpected reduction  ---> completed
# pay_loans  ---> completed
# account  ---> completed
# money_store  ---> completed
# mobile_money  ---> completed
# mobile_money_store  ---> completed
# money_transfer  ---> completed
# mobile_banking  ---> completed
# find_job  ---> completed
# clean  ---> completed
# food  ---> completed

# %% [markdown]
# # Employer (by Employer) Survey

# %%
class survey:
    def __init__(self,byEmployer):
        self.nigeria_byEmployer = byEmployer

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_byEmployer.copy()
        inc = byEmployer[byEmployer.columns[byEmployer.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'byEmployer'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_byEmployer.copy()
        inc = byEmployer[byEmployer.columns[byEmployer.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'byEmployer'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(byEmployer)
other_inc = emp.yes_no_question("Firm ID|SFD-EBE-010",['Firm ID'],"Other Income")
responsible  = emp.other_question("Firm ID|SFD-EBE-020",['Firm ID'],"Responsible")
expense  = emp.yes_no_question("Firm ID|SFD-EBE-030",['Firm ID'],"Major expense")
expectations  = emp.yes_no_question("Firm ID|SFD-EBE-040",['Firm ID'],"Expected expense")
worry  = emp.other_question("Firm ID|SFD-EBE-070",['Firm ID'],"Worry")
reduction  = emp.other_question("Firm ID|SFD-EBE-080",['Firm ID'],"Unexpected reduction")

byEmployer = [other_inc,responsible,expense,expectations,worry,reduction]
# Out:
# Other Income  ---> completed
# Responsible  ---> completed
# Major expense  ---> completed
# Expected expense  ---> completed
# Worry  ---> completed
# Unexpected reduction  ---> completed

# %% [markdown]
# # special events survey

# %%
class survey:
    def __init__(self,specialevents):
        self.nigeria_specialevents = specialevents

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_specialevents.copy()
        inc = specialevents[specialevents.columns[specialevents.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'specialevents'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_specialevents.copy()
        inc = specialevents[specialevents.columns[specialevents.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'specialevents'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(specialevents)
other_inc = emp.other_question("Firm ID|SFD-SEV-010",['Firm ID'],"Other Income")
responsible  = emp.other_question("Firm ID|SFD-SEV-020",['Firm ID'],"Responsible")
expense  = emp.yes_no_question("Firm ID|SFD-SEV-030",['Firm ID'],"Major expense")
expectations  = emp.yes_no_question("Firm ID|SFD-SEV-040",['Firm ID'],"Expected expense")
worry  = emp.yes_no_question("Firm ID|SFD-SEV-050",['Firm ID'],"Worry")
reduction  = emp.yes_no_question("Firm ID|SFD-SEV-070",['Firm ID'],"Unexpected reduction")
loss  = emp.yes_no_question("Firm ID|SFD-SEV-080",['Firm ID'],"loss")
events  = emp.yes_no_question("Firm ID|SFD-SEV-110",['Firm ID'],"events")
changes  = emp.yes_no_question("Firm ID|SFD-SEV-120",['Firm ID'],"changes")

specialevents = [other_inc,responsible,expense,expectations,worry,reduction,loss,events,changes]
# Out:
# Other Income  ---> completed
# Responsible  ---> completed
# Major expense  ---> completed
# Expected expense  ---> completed
# Worry  ---> completed
# Unexpected reduction  ---> completed
# loss  ---> completed
# events  ---> completed
# changes  ---> completed

# %% [markdown]
# # use of technology

# %%
class survey:
    def __init__(self,technology):
        self.nigeria_technology = technology

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_technology.copy()
        inc = technology[technology.columns[technology.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'technology'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_technology.copy()
        inc = technology[technology.columns[technology.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'technology'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(technology)
other_inc = emp.yes_no_question("Firm ID|SFD-UOT-010",['Firm ID'],"Other Income")
responsible  = emp.other_question("Firm ID|SFD-UOT-020",['Firm ID'],"Responsible")
expense  = emp.other_question("Firm ID|SFD-UOT-030",['Firm ID'],"Major expense")
expectations  = emp.yes_no_question("Firm ID|SFD-UOT-040",['Firm ID'],"Expected expense")
worry  = emp.yes_no_question("Firm ID|SFD-UOT-050",['Firm ID'],"Worry")
reduction  = emp.yes_no_question("Firm ID|SFD-UOT-060",['Firm ID'],"Unexpected reduction")
loss  = emp.yes_no_question("Firm ID|SFD-UOT-080",['Firm ID'],"loss")
events  = emp.yes_no_question("Firm ID|SFD-UOT-090",['Firm ID'],"events")
changes  = emp.other_question("Firm ID|SFD-UOT-100",['Firm ID'],"changes")
digital  = emp.yes_no_question("Firm ID|SFD-UOT-110",['Firm ID'],"digital")
purpose  = emp.yes_no_question("Firm ID|SFD-UOT-120",['Firm ID'],"purpose")
challenges  = emp.yes_no_question("Firm ID|SFD-UOT-130",['Firm ID'],"challenges")
specify  = emp.yes_no_question("Firm ID|SFD-UOT-140",['Firm ID'],"specify")

technology = [other_inc,responsible,expense,expectations,worry,reduction,loss,events,changes,digital,purpose,challenges,specify]
# Out:
# Other Income  ---> completed
# Responsible  ---> completed
# Major expense  ---> completed
# Expected expense  ---> completed
# Worry  ---> completed
# Unexpected reduction  ---> completed
# loss  ---> completed
# events  ---> completed
# changes  ---> completed
# digital  ---> completed
# purpose  ---> completed
# challenges  ---> completed
# specify  ---> completed

# %% [markdown]
# # manager survey

# %%
class survey:
    def __init__(self,manager):
        self.nigeria_manager = manager

    def yes_no_question(self,pattern,id_var,message):
        inc = self.nigeria_manager.copy()
        inc = manager[manager.columns[manager.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc['survey'] = 'manager'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[inc['value']=='Yes']
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
    def other_question(self,pattern,id_var,message):
        inc = self.nigeria_manager.copy()
        inc = manager[manager.columns[manager.columns.str.contains(pattern)]].melt(id_vars =id_var)
        inc = inc[~inc['variable'].str.contains("_feedback")]
        inc['survey'] = 'manager'
        inc['Question']  = [i.split('_')[0] for i in inc['variable']]
        inc['answer'] = [i.split('_')[1] if '_' in i else '' for i in inc['variable']]
        inc = inc[~inc['value'].isin(['-1',-1])]
        print(f'{message}  ---> completed')
        inc.columns = ['firm_id','variable','value','survey','question','answer']
        return inc.drop('variable',axis =1)
        
# employee qualitative
emp = survey(manager)
other_inc = emp.yes_no_question("Firm ID|SFD-MNS-010",['Firm ID'],"Other Income")
responsible  = emp.yes_no_question("Firm ID|SFD-MNS-050",['Firm ID'],"Responsible")
expense  = emp.other_question("Firm ID|SFD-MNS-060",['Firm ID'],"Major expense")
expectations  = emp.yes_no_question("Firm ID|SFD-MNS-070",['Firm ID'],"Expected expense")
worry  = emp.other_question("Firm ID|SFD-MNS-080",['Firm ID'],"Worry")
reduction  = emp.yes_no_question("Firm ID|SFD-MNS-090",['Firm ID'],"Unexpected reduction")
loss  = emp.yes_no_question("Firm ID|SFD-MNS-100",['Firm ID'],"loss")
events  = emp.other_question("Firm ID|SFD-MNS-110",['Firm ID'],"events")

manager = [other_inc,responsible,expense,expectations,worry,reduction,loss,events]
# Out:
# Other Income  ---> completed
# Responsible  ---> completed
# Major expense  ---> completed
# Expected expense  ---> completed
# Worry  ---> completed
# Unexpected reduction  ---> completed
# loss  ---> completed
# events  ---> completed

# %%
final = pd.concat(aspires + attitudes + Employee + customer_in_person + customer_phone + supplierperson + supplierphone
                 + competition + mckenzie + decisions + employeePPI + finance + formalization + gender + records + byEmployer
                 + specialevents + technology + manager)
final
# Out:
#             firm_id                                              value  \
# 3    KA-3B-FR3-1948                                                Yes
# 5    EN-1A-FR1-1716                                                Yes
# 8    KA-3B-FR3-2274                                                Yes
# 9    LA-2B-FR2-1819                                                Yes
# 12   EN-1A-FR1-2171                                                Yes
# ..              ...                                                ...
# 167  EN-3B-FR3-1672  Don’t like either, instead would like ……(specify)
# 168  EN-3C-FR4-3625   Get time from a coach or advisor on these topics
# 169  LA-1B-FR1-3041                                       Equally both
# 170  LA-4A-FR4-2508                                       Equally both
# 171  LA-5C-FR5-2173                                       Equally both
#
#           survey                                           question  \
# ...

# %%
print(final.shape)
final.to_excel('Outputs/aspirations_nigeria.xlsx')
print('final------> saved to disk')
print(often.head())
# Out:
# (108432, 5)
# final------> saved to disk
#           firm_id      value       survey  \
# 0  LA-2B-FR2-1406      Daily  aspirations
# 1  LA-2B-FR2-1444  Quarterly  aspirations
# 2  KA-1A-FR1-1002   Annually  aspirations
# 3  KA-3B-FR3-1948     Weekly  aspirations
# 4  KA-1A-FR1-1189      Daily  aspirations
#
#                                             question             answer
# 0  SFD-AST-050 How often do you track each of the...  Amount produced\t
# 1  SFD-AST-050 How often do you track each of the...  Amount produced\t
# 2  SFD-AST-050 How often do you track each of the...  Amount produced\t
# 3  SFD-AST-050 How often do you track each of the...  Amount produced\t
# 4  SFD-AST-050 How often do you track each of the...  Amount produced\t
